# %%
from langchain_community.embeddings import OllamaEmbeddings

# %%
embeddings = ( 
    OllamaEmbeddings(model = "gemma:2b")
  )  ## By default it uses Llama 2

# %%
embeddings
# Out:
# OllamaEmbeddings(base_url='http://localhost:11434', model='gemma:2b', embed_instruction='passage: ', query_instruction='query: ', mirostat=None, mirostat_eta=None, mirostat_tau=None, num_ctx=None, num_gpu=None, num_thread=None, repeat_last_n=None, repeat_penalty=None, temperature=None, stop=None, tfs_z=None, top_k=None, top_p=None, show_progress=False, headers=None, model_kwargs=None)

# %%
r1 = embeddings.embed_documents(
    [
        "Alpha is the first character of Greek Alphabet",
        "Beta is the second character of Greek Alphabet"
    ]
)

# %%
r1[0]
# Out:
# [-3.0493524074554443,
#  -1.661467432975769,
#  0.5248342156410217,
#  3.2757582664489746,
#  -0.019656382501125336,
#  0.40037965774536133,
#  0.3453487753868103,
#  0.5164486765861511,
#  1.4551613330841064,
#  -1.1431061029434204,
#  0.7533487677574158,
#  0.3727743327617645,
#  0.8191423416137695,
#  -0.6194363236427307,
#  -0.9994531869888306,
#  0.07724162936210632,
#  2.677584171295166,
#  -0.8494939208030701,
#  0.8504020571708679,
#  0.24138687551021576,
#  0.6578164100646973,
#  0.19890150427818298,
#  0.6114501953125,
#  0.5263760685920715,
#  -1.2777611017227173,
#  -1.5389785766601562,
#  -0.7788481712341309,
#  0.028065843507647514,
#  0.3769829273223877,
#  0.7034291625022888,
#  0.29656001925468445,
#  -0.012519662268459797,
#  0.45676133036613464,
#  0.5886010527610779,
#  -1.2400493621826172,
#  0.02471057139337063,
#  -0.6594933867454529,
#  1.1416853666305542,
#  0.4346216917037964,
#  0.3464440405368805,
#  2.1279304027557373,
#  0.6132683753967285,
# ...

# %%
len(r1[0])
# Out:
# 2048

# %%
embeddings.embed_query("Alpha is the first character of Greek Alphabet")
# Out:
# [-3.2859373092651367,
#  -1.9168720245361328,
#  1.349960207939148,
#  3.080212354660034,
#  0.607787549495697,
#  -0.03242577612400055,
#  -0.4705020487308502,
#  0.24449190497398376,
#  0.8796339631080627,
#  -0.6159512996673584,
#  0.9326137900352478,
#  0.360332727432251,
#  0.5346641540527344,
#  -0.7201794981956482,
#  -0.887955904006958,
#  0.4871959984302521,
#  2.8934550285339355,
#  -0.019931480288505554,
#  0.5915290713310242,
#  -0.18698503077030182,
#  1.2272274494171143,
#  0.4767681956291199,
#  0.9024008512496948,
#  0.276755154132843,
#  -1.3509658575057983,
#  -2.4180796146392822,
#  -0.9334036111831665,
#  0.1455891728401184,
#  0.27978625893592834,
#  0.20057256519794464,
#  -0.08186157047748566,
#  0.7373408675193787,
#  0.6871781945228577,
#  0.16263823211193085,
#  -1.1219370365142822,
#  0.04997771233320236,
#  -0.49674737453460693,
#  1.6051501035690308,
#  -0.19024495780467987,
#  0.02803872898221016,
#  1.6446608304977417,
#  0.4614546000957489,
# ...
